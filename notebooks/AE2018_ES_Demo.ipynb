# %% [markdown]
# # Strategie ewolucyjne
#
# Notebook pokazuje podstawowe mechanizmy strategii ewolucyjnych.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from matplotlib import cm

# %matplotlib inline

# %% [markdown]
# ## Przykładowe problemy testowe

# %%
# Sphere function (minimum at 0)
def objective_function_F1(X):
    return - np.sum(X**2, axis=1)

# Sphere function - modified
def objective_function_F1a(X):
    return - (X[:, 0]**2 + 9*X[:, 1]**2)

# Sphere function - modified
def objective_function_F1b(X):
    return - (X[:, 0]**2 + 625*X[:, 1]**2)

# Sphere function - modified
def objective_function_F1c(X):
    return - (X[:, 0]**2 + 2*X[:, 1]**2 - 2 * X[:, 0] * X[:, 1])

# %%
# Rastrigin function (minimum at 0)
def objective_function_F6(X):
    return - 10.0 * X.shape[1] - np.sum(X**2, axis=1) + 10.0 * np.sum(np.cos(2 * np.pi * X), axis=1)

# %%
# Schwefel function (minimum at 420.9687)
# (REMARK: should be considered only on [-500, 500]^d, because there are better minima outside)
def objective_function_F7(X):
    return - 418.9829 * X.shape[1] + np.sum(X * np.sin(np.sqrt(np.abs(X))), axis=1)

# %%
# Griewank function (minimum at 0)
def objective_function_F8(X):
    return - 1 - np.sum(X**2 / 4000, axis=1) + np.prod(np.cos(X / np.sqrt(np.linspace(1, X.shape[1], X.shape[1]))), axis=1)

# %%
def plot_3D_benchmark_function(objective_function, domain_X, domain_Y, title):
    fig = plt.figure(figsize=(12, 8))
    ax = fig.add_subplot(projection='3d')
    X, Y = np.meshgrid(domain_X, domain_Y)
    Z = - objective_function(np.vstack([X.ravel(), Y.ravel()]).T).reshape(X.shape[0], X.shape[1])
    surf = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=cm.hot, linewidth=0, antialiased=True)
    plt.title(title)
    plt.show()

# %%
def plot_contour_benchmark_function(objective_function, domain_X, domain_Y, title):
    plt.figure(figsize=(9, 9))
    X, Y = np.meshgrid(domain_X, domain_Y)
    Z = - objective_function(np.vstack([X.ravel(), Y.ravel()]).T).reshape(X.shape[0], X.shape[1])
    plt.contour(X, Y, Z, 50)
    plt.title(title)
    plt.show()

# %%
plot_3D_benchmark_function(objective_function_F1c, np.arange(-5, 5, 0.25), np.arange(-5, 5, 0.25), 'Sphere Function')

# %%
plot_contour_benchmark_function(objective_function_F1, np.arange(-5, 5, 0.25), np.arange(-5, 5, 0.25), 'Sphere Function')

# %%
plot_3D_benchmark_function(objective_function_F6, np.arange(-5, 5, 0.05), np.arange(-5, 5, 0.05), 'Rastrigin Function')

# %%
plot_contour_benchmark_function(objective_function_F6, np.arange(-5, 5, 0.05), np.arange(-5, 5, 0.05), 'Rastrigin Function')

# %%
plot_3D_benchmark_function(objective_function_F7, np.arange(-500, 500, 5), np.arange(-500, 500, 5), 'Schwefel Function')

# %%
plot_contour_benchmark_function(objective_function_F7, np.arange(-500, 500, 5), np.arange(-500, 500, 5), 'Schwefel Function')

# %%
plot_3D_benchmark_function(objective_function_F8, np.arange(-100, 100, 0.5), np.arange(-100, 100, 0.5), 'Griewank Function')

# %%
plot_contour_benchmark_function(objective_function_F8, np.arange(-100, 100, 0.5), np.arange(-100, 100, 0.5), 'Griewank Function')

# %% [markdown]
# ## Przykładowe modele mutacji

# %%
N = 250
d = 2

objective_function = objective_function_F1a

original_individual = np.array([[1, 1]])

# %% [markdown]
# ### Przykład 1:
#
# $x_i = x_i + \varepsilon_i$, gdzie $\varepsilon_i$ ma rozkład normalny $\mathcal{N}(0, \sigma^2)$, zaś $\sigma$ jest taka sama dla wszystkich $i = 1, 2, \ldots, d$

# %%
sigma = 0.25
mutations = original_individual + sigma * np.random.randn(N, d)

# %%
domain_X = np.arange(-5, 5, 0.25)
domain_Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(domain_X, domain_Y)
Z = - objective_function(np.vstack([X.ravel(), Y.ravel()]).T).reshape(X.shape[0], X.shape[1])

plt.figure(figsize=(9, 9))
plt.contour(X, Y, Z, 50)
plt.plot(mutations[:, 0], mutations[:, 1], 'ro')
plt.plot(original_individual[0, 0], original_individual[0, 1], 'k*', markersize=24)
plt.title('Mutation 1')
plt.show()

# %% [markdown]
# ### Przykład 2:
#
# $x_i = x_i + \varepsilon_i$, gdzie $\varepsilon_i$ ma rozkład normalny $\mathcal{N}(0, \sigma_i^2)$, zaś $\sigma_i$ może być różna dla różnych $i = 1, 2, \ldots, d$

# %%
sigma = np.array([0.01, 1])
mutations = original_individual + sigma * np.random.randn(N, d)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 sigma = np.array([0.01, 1])
# ----> 2 mutations = original_individual + sigma * np.random.randn(N, d)
#
# NameError: name 'original_individual' is not defined

# %%
domain_X = np.arange(-5, 5, 0.25)
domain_Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(domain_X, domain_Y)
Z = - objective_function(np.vstack([X.ravel(), Y.ravel()]).T).reshape(X.shape[0], X.shape[1])

plt.figure(figsize=(9, 9))
plt.contour(X, Y, Z, 50)
plt.plot(mutations[:, 0], mutations[:, 1], 'ro')
plt.plot(original_individual[0, 0], original_individual[0, 1], 'k*', markersize=24)
plt.title('Mutation 2')
plt.show()

# %% [markdown]
# ### Przykład 3:
#
# $\mathbf{x} = \mathbf{x} + \boldsymbol{\varepsilon}$, gdzie $\boldsymbol{\varepsilon}$ ma wielowymiarowy rozkład normalny $\mathcal{N}(\mathbf{0}, \boldsymbol{\Sigma})$

# %%
S = np.array([[0.25, 0.25],[0.25, 0.5]])
mutations = original_individual + np.dot(np.random.randn(N, d), np.linalg.cholesky(S).T)

# %%
domain_X = np.arange(-5, 5, 0.25)
domain_Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(domain_X, domain_Y)
Z = - objective_function(np.vstack([X.ravel(), Y.ravel()]).T).reshape(X.shape[0], X.shape[1])

plt.figure(figsize=(9, 9))
plt.contour(X, Y, Z, 50)
plt.plot(mutations[:, 0], mutations[:, 1], 'ro')
plt.plot(original_individual[0, 0], original_individual[0, 1], 'k*', markersize=24)
plt.title('Mutation 3')
plt.show()

# %% [markdown]
# ## Przykładowa strategia ewolucyjna

# %%
def es(objective_function, chromosome_length, population_size, number_of_iterations, number_of_offspring, number_of_parents, sigma, tau, tau_0, S=None, mutation_f="mutation_2", log_frequency=1):
    best_solution = np.empty((1, chromosome_length))
    best_solution_objective_value = -np.inf

    log_objective_values = np.empty((number_of_iterations, 4))
    log_best_solutions = np.empty((number_of_iterations, chromosome_length))
    log_best_sigmas = np.empty((number_of_iterations, chromosome_length))

    # generating an initial population
    current_population_solutions = 100.0 * np.random.rand(population_size, chromosome_length)

    if mutation_f == "mutation_1":
        current_population_sigmas = sigma * np.ones((population_size, 1))
    elif mutation_f == "mutation_2":
        current_population_sigmas = sigma * np.ones((population_size, chromosome_length))
    elif mutation_f == "mutation_3":
        L_T = np.linalg.cholesky(S).T
        current_population_sigmas = sigma * np.ones((population_size, 1))

    # evaluating the objective function on the current population
    current_population_objective_values = objective_function(current_population_solutions)

    for t in range(number_of_iterations):

        # selecting the parent indices by the roulette wheel method
        fitness_values = current_population_objective_values - current_population_objective_values.min()
        if fitness_values.sum() > 0:
            fitness_values = fitness_values / fitness_values.sum()
        else:
            fitness_values = 1.0 / population_size * np.ones(population_size)
        parent_indices = np.random.choice(population_size, (number_of_offspring, number_of_parents), True, fitness_values).astype(np.int64)

        # creating the children population by Global Intermediere Recombination
        children_population_solutions = np.zeros((number_of_offspring, chromosome_length))
        # dynamic shape based on mutation type
        if mutation_f == "mutation_1" or mutation_f == "mutation_3":
            children_population_sigmas = np.zeros((number_of_offspring, 1))
        else:
            children_population_sigmas = np.zeros((number_of_offspring, chromosome_length))
        for i in range(number_of_offspring):
            children_population_solutions[i, :] = current_population_solutions[parent_indices[i, :], :].mean(axis=0)
            children_population_sigmas[i, :] = current_population_sigmas[parent_indices[i, :], :].mean(axis=0)

        # mutating the children population by adding random gaussian noise
        if mutation_f == "mutation_1" or mutation_f == "mutation_3":
            children_population_sigmas = children_population_sigmas * np.exp(tau * np.random.randn(number_of_offspring, 1) + tau_0 * np.random.randn(number_of_offspring, 1))
        elif mutation_f == "mutation_2":
            children_population_sigmas = children_population_sigmas * np.exp(tau * np.random.randn(number_of_offspring, chromosome_length) + tau_0 * np.random.randn(number_of_offspring, 1))

        if mutation_f == "mutation_1" or mutation_f == "mutation_2":
            children_population_solutions = children_population_solutions + children_population_sigmas * np.random.randn(number_of_offspring, chromosome_length)
        elif mutation_f == "mutation_3":
            Z = np.random.randn(number_of_offspring, chromosome_length)
            children_population_solutions = children_population_solutions + children_population_sigmas * np.dot(Z, L_T)


        # evaluating the objective function on the children population
        children_population_objective_values = objective_function(children_population_solutions)

        # replacing the current population by (Mu + Lambda) Replacement
        current_population_objective_values = np.hstack([current_population_objective_values, children_population_objective_values])
        current_population_solutions = np.vstack([current_population_solutions, children_population_solutions])
        current_population_sigmas = np.vstack([current_population_sigmas, children_population_sigmas])

        I = np.argsort(current_population_objective_values)[::-1]
        current_population_solutions = current_population_solutions[I[:population_size], :]
        current_population_sigmas = current_population_sigmas[I[:population_size], :]
        current_population_objective_values = current_population_objective_values[I[:population_size]]

        # recording some statistics
        if best_solution_objective_value < current_population_objective_values[0]:
            best_solution = current_population_solutions[0, :]
            best_solution_objective_value = current_population_objective_values[0]
        log_objective_values[t, :] = [current_population_objective_values.min(), current_population_objective_values.max(), current_population_objective_values.mean(), current_population_objective_values.std()]
        log_best_solutions[t, :] = current_population_solutions[0, :]
        if mutation_f == "mutation_1" or mutation_f == "mutation_3":
            log_best_sigmas[t, :] = current_population_sigmas[0, 0]
        else:
            log_best_sigmas[t, :] = current_population_sigmas[0, :]

        if log_frequency != -1 and np.mod(t, log_frequency) == 0:
            print("Iteration %04d : best score = %0.8f, mean score = %0.8f." % (t, log_objective_values[:t+1, 1].max(), log_objective_values[t, 2]))

    return best_solution_objective_value, best_solution, log_objective_values, log_best_solutions, log_best_sigmas

# %% [markdown]
# ### Działanie strategii ewolucyjnej dla funkcji sferycznej F1

# %%
d = 10
N = 2000
T = 100

best_objective_value, best_chromosome, history_objective_values, history_best_chromosome, history_best_sigmas = es(
    objective_function_F1, d, N, T, 2*N, 2, 50.0, 1/np.sqrt(2*d), 1/np.sqrt(2*np.sqrt(d)), 10)

plt.figure(figsize=(18, 4))
plt.plot(history_objective_values[:, 0], 'r-')
plt.plot(history_objective_values[:, 1], 'r-')
plt.plot(history_objective_values[:, 2], 'r-')
plt.xlabel('iteration')
plt.ylabel('objective function value')
plt.title('min/avg/max objective function values')
plt.show()

plt.figure(figsize=(18, 4))
plt.plot(history_best_sigmas, 'r-')
plt.xlabel('iteration')
plt.ylabel('sigma value')
plt.title('best sigmas')
plt.show()
# Out:
# Iteration 0000 : best score = -7543.69138807, mean score = -26247.55132488.
# Iteration 0010 : best score = -28.65981886, mean score = -221.48365706.
# Iteration 0020 : best score = -0.06531846, mean score = -0.61753392.
# Iteration 0030 : best score = -0.00021806, mean score = -0.00132214.
# Iteration 0040 : best score = -0.00000047, mean score = -0.00000273.
# Iteration 0050 : best score = -0.00000000, mean score = -0.00000000.
# Iteration 0060 : best score = -0.00000000, mean score = -0.00000000.
# Iteration 0070 : best score = -0.00000000, mean score = -0.00000000.
# Iteration 0080 : best score = -0.00000000, mean score = -0.00000000.
# Iteration 0090 : best score = -0.00000000, mean score = -0.00000000.

# %% [markdown]
# ### Działanie strategii ewolucyjnej dla funkcji Rastrigina F6

# %%
d = 10
N = 2000
T = 100

best_objective_value, best_chromosome, history_objective_values, history_best_chromosome, history_best_sigmas = es(
    objective_function_F6, d, N, T, 2*N, 2, 50.0, 1/np.sqrt(2*d), 1/np.sqrt(2*np.sqrt(d)), 10)

plt.figure(figsize=(18, 4))
plt.plot(history_objective_values[:, 0], 'r-')
plt.plot(history_objective_values[:, 1], 'r-')
plt.plot(history_objective_values[:, 2], 'r-')
plt.xlabel('iteration')
plt.ylabel('objective function value')
plt.title('min/avg/max objective function values')
plt.show()

plt.figure(figsize=(18, 4))
plt.plot(history_best_sigmas, 'r-')
plt.xlabel('iteration')
plt.ylabel('sigma value')
plt.title('best sigmas')
plt.show()
# Out:
# Iteration 0000 : best score = -4553.92860662, mean score = -26256.13622285.
# Iteration 0010 : best score = -102.79853784, mean score = -320.99057131.
# Iteration 0020 : best score = -32.82245779, mean score = -76.15431301.
# Iteration 0030 : best score = -28.31908931, mean score = -62.28890062.
# Iteration 0040 : best score = -23.56646793, mean score = -56.31183865.
# Iteration 0050 : best score = -15.84139558, mean score = -52.12962001.
# Iteration 0060 : best score = -11.60092779, mean score = -46.11050538.
# Iteration 0070 : best score = -1.02728299, mean score = -1.21674690.
# Iteration 0080 : best score = -0.99505315, mean score = -0.99546590.
# Iteration 0090 : best score = -0.99495921, mean score = -0.99496011.

# %% [markdown]
# ### Działanie strategii ewolucyjnej dla funkcji Griewanka F8

# %%
d = 10
N = 2000
T = 100

best_objective_value, best_chromosome, history_objective_values, history_best_chromosome, history_best_sigmas = es(
    objective_function_F8, d, N, T, 2*N, 2, 50.0, 1/np.sqrt(2*d), 1/np.sqrt(2*np.sqrt(d)), 10)

plt.figure(figsize=(18, 4))
plt.plot(history_objective_values[:, 0], 'r-')
plt.plot(history_objective_values[:, 1], 'r-')
plt.plot(history_objective_values[:, 2], 'r-')
plt.xlabel('iteration')
plt.ylabel('objective function value')
plt.title('min/avg/max objective function values')
plt.show()

plt.figure(figsize=(18, 4))
plt.plot(history_best_sigmas, 'r-')
plt.xlabel('iteration')
plt.ylabel('sigma value')
plt.title('best sigmas')
plt.show()
# Out:
# Iteration 0000 : best score = -2.50939551, mean score = -7.61166503.
# Iteration 0010 : best score = -0.66744108, mean score = -1.05997533.
# Iteration 0020 : best score = -0.07671558, mean score = -0.51944560.
# Iteration 0030 : best score = -0.00055707, mean score = -0.00283236.
# Iteration 0040 : best score = -0.00000459, mean score = -0.00002138.
# Iteration 0050 : best score = -0.00000001, mean score = -0.00000009.
# Iteration 0060 : best score = -0.00000000, mean score = -0.00000000.
# Iteration 0070 : best score = -0.00000000, mean score = -0.00000000.
# Iteration 0080 : best score = -0.00000000, mean score = -0.00000000.
# Iteration 0090 : best score = 0.00000000, mean score = 0.00000000.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 8
#       3 T = 100
#       5 best_objective_value, best_chromosome, history_objective_values, history_best_chromosome, history_best_sigmas = es(
#       6     objective_function_F8, d, N, T, 2*N, 2, 50.0, 1/np.sqrt(2*d), 1/np.sqrt(2*np.sqrt(d)), 10)
# ----> 8 plt.figure(figsize=(18, 4))
#       9 plt.plot(history_objective_values[:, 0], 'r-')
#      10 plt.plot(history_objective_values[:, 1], 'r-')
#
# NameError: name 'plt' is not defined

# %% [markdown]
# # Zadanie 1

# %%
benchmark_functions = {
    "Sphere_F1": objective_function_F1,
    "Rastrigin_F6": objective_function_F6,
    "Schwefel_F7": objective_function_F7,
    "Griewank_F8": objective_function_F8,
}


dims = [10, 20, 50, 100]
pop_sizes = [200, 1000]
sigmas = [10.0, 50.0]
T = 200
num_runs = 3

results = []

for func_name, func in benchmark_functions.items():
    for d in dims:
        tau = 1.0 / np.sqrt(2.0 * d)
        tau_0 = 1.0 / np.sqrt(2.0 * np.sqrt(d))

        for N in pop_sizes:
            for sigma in sigmas:
                for run in range(num_runs):
                    print(f"Running {func_name}, d={d}, N={N}, sigma={sigma}, run={run+1}/{num_runs}")

                    best_objective_value, best_chromosome, _, _, _ = es(
                        objective_function=func,
                        chromosome_length=d,
                        population_size=N,
                        number_of_iterations=T,
                        number_of_offspring=2 * N,
                        number_of_parents=2,
                        sigma=sigma,
                        tau=tau,
                        tau_0=tau_0,
                        log_frequency=-1, # disable logging
                    )

                    results.append({
                        "function": func_name,
                        "dim": d,
                        "N": N,
                        "sigma": sigma,
                        "best_objective_value": best_objective_value,
                    })


df_results = pd.DataFrame(results)
# Out:
# Running Sphere_F1, d=10, N=200, sigma=10.0, run=1/3
# Running Sphere_F1, d=10, N=200, sigma=10.0, run=2/3
# Running Sphere_F1, d=10, N=200, sigma=10.0, run=3/3
# Running Sphere_F1, d=10, N=200, sigma=50.0, run=1/3
# Running Sphere_F1, d=10, N=200, sigma=50.0, run=2/3
# Running Sphere_F1, d=10, N=200, sigma=50.0, run=3/3
# Running Sphere_F1, d=10, N=1000, sigma=10.0, run=1/3
# Running Sphere_F1, d=10, N=1000, sigma=10.0, run=2/3
# Running Sphere_F1, d=10, N=1000, sigma=10.0, run=3/3
# Running Sphere_F1, d=10, N=1000, sigma=50.0, run=1/3
# Running Sphere_F1, d=10, N=1000, sigma=50.0, run=2/3
# Running Sphere_F1, d=10, N=1000, sigma=50.0, run=3/3
# Running Sphere_F1, d=20, N=200, sigma=10.0, run=1/3
# Running Sphere_F1, d=20, N=200, sigma=10.0, run=2/3
# Running Sphere_F1, d=20, N=200, sigma=10.0, run=3/3
# Running Sphere_F1, d=20, N=200, sigma=50.0, run=1/3
# Running Sphere_F1, d=20, N=200, sigma=50.0, run=2/3
# Running Sphere_F1, d=20, N=200, sigma=50.0, run=3/3
# Running Sphere_F1, d=20, N=1000, sigma=10.0, run=1/3
# Running Sphere_F1, d=20, N=1000, sigma=10.0, run=2/3
# Running Sphere_F1, d=20, N=1000, sigma=10.0, run=3/3
# Running Sphere_F1, d=20, N=1000, sigma=50.0, run=1/3
# Running Sphere_F1, d=20, N=1000, sigma=50.0, run=2/3
# Running Sphere_F1, d=20, N=1000, sigma=50.0, run=3/3
# Running Sphere_F1, d=50, N=200, sigma=10.0, run=1/3
# Running Sphere_F1, d=50, N=200, sigma=10.0, run=2/3
# Running Sphere_F1, d=50, N=200, sigma=10.0, run=3/3
# Running Sphere_F1, d=50, N=200, sigma=50.0, run=1/3
# Running Sphere_F1, d=50, N=200, sigma=50.0, run=2/3
# Running Sphere_F1, d=50, N=200, sigma=50.0, run=3/3
# Running Sphere_F1, d=50, N=1000, sigma=10.0, run=1/3
# Running Sphere_F1, d=50, N=1000, sigma=10.0, run=2/3
# Running Sphere_F1, d=50, N=1000, sigma=10.0, run=3/3
# Running Sphere_F1, d=50, N=1000, sigma=50.0, run=1/3
# Running Sphere_F1, d=50, N=1000, sigma=50.0, run=2/3
# Running Sphere_F1, d=50, N=1000, sigma=50.0, run=3/3
# Running Sphere_F1, d=100, N=200, sigma=10.0, run=1/3
# Running Sphere_F1, d=100, N=200, sigma=10.0, run=2/3
# Running Sphere_F1, d=100, N=200, sigma=10.0, run=3/3
# Running Sphere_F1, d=100, N=200, sigma=50.0, run=1/3
# Running Sphere_F1, d=100, N=200, sigma=50.0, run=2/3
# Running Sphere_F1, d=100, N=200, sigma=50.0, run=3/3
# Running Sphere_F1, d=100, N=1000, sigma=10.0, run=1/3
# Running Sphere_F1, d=100, N=1000, sigma=10.0, run=2/3
# Running Sphere_F1, d=100, N=1000, sigma=10.0, run=3/3
# Running Sphere_F1, d=100, N=1000, sigma=50.0, run=1/3
# Running Sphere_F1, d=100, N=1000, sigma=50.0, run=2/3
# Running Sphere_F1, d=100, N=1000, sigma=50.0, run=3/3
# Running Rastrigin_F6, d=10, N=200, sigma=10.0, run=1/3
# Running Rastrigin_F6, d=10, N=200, sigma=10.0, run=2/3
# Running Rastrigin_F6, d=10, N=200, sigma=10.0, run=3/3
# Running Rastrigin_F6, d=10, N=200, sigma=50.0, run=1/3
# Running Rastrigin_F6, d=10, N=200, sigma=50.0, run=2/3
# Running Rastrigin_F6, d=10, N=200, sigma=50.0, run=3/3
# Running Rastrigin_F6, d=10, N=1000, sigma=10.0, run=1/3
# Running Rastrigin_F6, d=10, N=1000, sigma=10.0, run=2/3
# Running Rastrigin_F6, d=10, N=1000, sigma=10.0, run=3/3
# Running Rastrigin_F6, d=10, N=1000, sigma=50.0, run=1/3
# Running Rastrigin_F6, d=10, N=1000, sigma=50.0, run=2/3
# Running Rastrigin_F6, d=10, N=1000, sigma=50.0, run=3/3
# Running Rastrigin_F6, d=20, N=200, sigma=10.0, run=1/3
# Running Rastrigin_F6, d=20, N=200, sigma=10.0, run=2/3
# Running Rastrigin_F6, d=20, N=200, sigma=10.0, run=3/3
# Running Rastrigin_F6, d=20, N=200, sigma=50.0, run=1/3
# Running Rastrigin_F6, d=20, N=200, sigma=50.0, run=2/3
# Running Rastrigin_F6, d=20, N=200, sigma=50.0, run=3/3
# Running Rastrigin_F6, d=20, N=1000, sigma=10.0, run=1/3
# Running Rastrigin_F6, d=20, N=1000, sigma=10.0, run=2/3
# Running Rastrigin_F6, d=20, N=1000, sigma=10.0, run=3/3
# Running Rastrigin_F6, d=20, N=1000, sigma=50.0, run=1/3
# Running Rastrigin_F6, d=20, N=1000, sigma=50.0, run=2/3
# Running Rastrigin_F6, d=20, N=1000, sigma=50.0, run=3/3
# Running Rastrigin_F6, d=50, N=200, sigma=10.0, run=1/3
# Running Rastrigin_F6, d=50, N=200, sigma=10.0, run=2/3
# Running Rastrigin_F6, d=50, N=200, sigma=10.0, run=3/3
# Running Rastrigin_F6, d=50, N=200, sigma=50.0, run=1/3
# Running Rastrigin_F6, d=50, N=200, sigma=50.0, run=2/3
# Running Rastrigin_F6, d=50, N=200, sigma=50.0, run=3/3
# Running Rastrigin_F6, d=50, N=1000, sigma=10.0, run=1/3
# Running Rastrigin_F6, d=50, N=1000, sigma=10.0, run=2/3
# Running Rastrigin_F6, d=50, N=1000, sigma=10.0, run=3/3
# Running Rastrigin_F6, d=50, N=1000, sigma=50.0, run=1/3
# Running Rastrigin_F6, d=50, N=1000, sigma=50.0, run=2/3
# Running Rastrigin_F6, d=50, N=1000, sigma=50.0, run=3/3
# Running Rastrigin_F6, d=100, N=200, sigma=10.0, run=1/3
# Running Rastrigin_F6, d=100, N=200, sigma=10.0, run=2/3
# Running Rastrigin_F6, d=100, N=200, sigma=10.0, run=3/3
# Running Rastrigin_F6, d=100, N=200, sigma=50.0, run=1/3
# Running Rastrigin_F6, d=100, N=200, sigma=50.0, run=2/3
# Running Rastrigin_F6, d=100, N=200, sigma=50.0, run=3/3
# Running Rastrigin_F6, d=100, N=1000, sigma=10.0, run=1/3
# Running Rastrigin_F6, d=100, N=1000, sigma=10.0, run=2/3
# Running Rastrigin_F6, d=100, N=1000, sigma=10.0, run=3/3
# Running Rastrigin_F6, d=100, N=1000, sigma=50.0, run=1/3
# Running Rastrigin_F6, d=100, N=1000, sigma=50.0, run=2/3
# Running Rastrigin_F6, d=100, N=1000, sigma=50.0, run=3/3
# Running Schwefel_F7, d=10, N=200, sigma=10.0, run=1/3
# Running Schwefel_F7, d=10, N=200, sigma=10.0, run=2/3
# Running Schwefel_F7, d=10, N=200, sigma=10.0, run=3/3
# Running Schwefel_F7, d=10, N=200, sigma=50.0, run=1/3
# Running Schwefel_F7, d=10, N=200, sigma=50.0, run=2/3
# Running Schwefel_F7, d=10, N=200, sigma=50.0, run=3/3
# Running Schwefel_F7, d=10, N=1000, sigma=10.0, run=1/3
# Running Schwefel_F7, d=10, N=1000, sigma=10.0, run=2/3
# Running Schwefel_F7, d=10, N=1000, sigma=10.0, run=3/3
# Running Schwefel_F7, d=10, N=1000, sigma=50.0, run=1/3
# Running Schwefel_F7, d=10, N=1000, sigma=50.0, run=2/3
# Running Schwefel_F7, d=10, N=1000, sigma=50.0, run=3/3
# Running Schwefel_F7, d=20, N=200, sigma=10.0, run=1/3
# Running Schwefel_F7, d=20, N=200, sigma=10.0, run=2/3
# Running Schwefel_F7, d=20, N=200, sigma=10.0, run=3/3
# Running Schwefel_F7, d=20, N=200, sigma=50.0, run=1/3
# Running Schwefel_F7, d=20, N=200, sigma=50.0, run=2/3
# Running Schwefel_F7, d=20, N=200, sigma=50.0, run=3/3
# Running Schwefel_F7, d=20, N=1000, sigma=10.0, run=1/3
# Running Schwefel_F7, d=20, N=1000, sigma=10.0, run=2/3
# Running Schwefel_F7, d=20, N=1000, sigma=10.0, run=3/3
# Running Schwefel_F7, d=20, N=1000, sigma=50.0, run=1/3
# Running Schwefel_F7, d=20, N=1000, sigma=50.0, run=2/3
# Running Schwefel_F7, d=20, N=1000, sigma=50.0, run=3/3
# Running Schwefel_F7, d=50, N=200, sigma=10.0, run=1/3
# Running Schwefel_F7, d=50, N=200, sigma=10.0, run=2/3
# Running Schwefel_F7, d=50, N=200, sigma=10.0, run=3/3
# Running Schwefel_F7, d=50, N=200, sigma=50.0, run=1/3
# Running Schwefel_F7, d=50, N=200, sigma=50.0, run=2/3
# Running Schwefel_F7, d=50, N=200, sigma=50.0, run=3/3
# Running Schwefel_F7, d=50, N=1000, sigma=10.0, run=1/3
# Running Schwefel_F7, d=50, N=1000, sigma=10.0, run=2/3
# Running Schwefel_F7, d=50, N=1000, sigma=10.0, run=3/3
# Running Schwefel_F7, d=50, N=1000, sigma=50.0, run=1/3
# Running Schwefel_F7, d=50, N=1000, sigma=50.0, run=2/3
# Running Schwefel_F7, d=50, N=1000, sigma=50.0, run=3/3
# Running Schwefel_F7, d=100, N=200, sigma=10.0, run=1/3
# Running Schwefel_F7, d=100, N=200, sigma=10.0, run=2/3
# Running Schwefel_F7, d=100, N=200, sigma=10.0, run=3/3
# Running Schwefel_F7, d=100, N=200, sigma=50.0, run=1/3
# Running Schwefel_F7, d=100, N=200, sigma=50.0, run=2/3
# Running Schwefel_F7, d=100, N=200, sigma=50.0, run=3/3
# Running Schwefel_F7, d=100, N=1000, sigma=10.0, run=1/3
# Running Schwefel_F7, d=100, N=1000, sigma=10.0, run=2/3
# Running Schwefel_F7, d=100, N=1000, sigma=10.0, run=3/3
# Running Schwefel_F7, d=100, N=1000, sigma=50.0, run=1/3
# Running Schwefel_F7, d=100, N=1000, sigma=50.0, run=2/3
# Running Schwefel_F7, d=100, N=1000, sigma=50.0, run=3/3
# Running Griewank_F8, d=10, N=200, sigma=10.0, run=1/3
# Running Griewank_F8, d=10, N=200, sigma=10.0, run=2/3
# Running Griewank_F8, d=10, N=200, sigma=10.0, run=3/3
# Running Griewank_F8, d=10, N=200, sigma=50.0, run=1/3
# Running Griewank_F8, d=10, N=200, sigma=50.0, run=2/3
# Running Griewank_F8, d=10, N=200, sigma=50.0, run=3/3
# Running Griewank_F8, d=10, N=1000, sigma=10.0, run=1/3
# Running Griewank_F8, d=10, N=1000, sigma=10.0, run=2/3
# Running Griewank_F8, d=10, N=1000, sigma=10.0, run=3/3
# Running Griewank_F8, d=10, N=1000, sigma=50.0, run=1/3
# Running Griewank_F8, d=10, N=1000, sigma=50.0, run=2/3
# Running Griewank_F8, d=10, N=1000, sigma=50.0, run=3/3
# Running Griewank_F8, d=20, N=200, sigma=10.0, run=1/3
# Running Griewank_F8, d=20, N=200, sigma=10.0, run=2/3
# Running Griewank_F8, d=20, N=200, sigma=10.0, run=3/3
# Running Griewank_F8, d=20, N=200, sigma=50.0, run=1/3
# Running Griewank_F8, d=20, N=200, sigma=50.0, run=2/3
# Running Griewank_F8, d=20, N=200, sigma=50.0, run=3/3
# Running Griewank_F8, d=20, N=1000, sigma=10.0, run=1/3
# Running Griewank_F8, d=20, N=1000, sigma=10.0, run=2/3
# Running Griewank_F8, d=20, N=1000, sigma=10.0, run=3/3
# Running Griewank_F8, d=20, N=1000, sigma=50.0, run=1/3
# Running Griewank_F8, d=20, N=1000, sigma=50.0, run=2/3
# Running Griewank_F8, d=20, N=1000, sigma=50.0, run=3/3
# Running Griewank_F8, d=50, N=200, sigma=10.0, run=1/3
# Running Griewank_F8, d=50, N=200, sigma=10.0, run=2/3
# Running Griewank_F8, d=50, N=200, sigma=10.0, run=3/3
# Running Griewank_F8, d=50, N=200, sigma=50.0, run=1/3
# Running Griewank_F8, d=50, N=200, sigma=50.0, run=2/3
# Running Griewank_F8, d=50, N=200, sigma=50.0, run=3/3
# Running Griewank_F8, d=50, N=1000, sigma=10.0, run=1/3
# Running Griewank_F8, d=50, N=1000, sigma=10.0, run=2/3
# Running Griewank_F8, d=50, N=1000, sigma=10.0, run=3/3
# Running Griewank_F8, d=50, N=1000, sigma=50.0, run=1/3
# Running Griewank_F8, d=50, N=1000, sigma=50.0, run=2/3
# Running Griewank_F8, d=50, N=1000, sigma=50.0, run=3/3
# Running Griewank_F8, d=100, N=200, sigma=10.0, run=1/3
# Running Griewank_F8, d=100, N=200, sigma=10.0, run=2/3
# Running Griewank_F8, d=100, N=200, sigma=10.0, run=3/3
# Running Griewank_F8, d=100, N=200, sigma=50.0, run=1/3
# Running Griewank_F8, d=100, N=200, sigma=50.0, run=2/3
# Running Griewank_F8, d=100, N=200, sigma=50.0, run=3/3
# Running Griewank_F8, d=100, N=1000, sigma=10.0, run=1/3
# Running Griewank_F8, d=100, N=1000, sigma=10.0, run=2/3
# Running Griewank_F8, d=100, N=1000, sigma=10.0, run=3/3
# Running Griewank_F8, d=100, N=1000, sigma=50.0, run=1/3
# Running Griewank_F8, d=100, N=1000, sigma=50.0, run=2/3
# Running Griewank_F8, d=100, N=1000, sigma=50.0, run=3/3

# %%
df_results
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df_results
#
# NameError: name 'df_results' is not defined

# %%
summary = (
    df_results
    .groupby(["function", "dim", "N", "sigma"])["best_objective_value"]
    .agg(["mean", "min", "max"])
    .reset_index()
)

summary
# Out:
#        function  dim     N  sigma          mean           min           max
# 0   Griewank_F8   10   200   10.0 -2.543619e-02 -4.428776e-02 -1.477978e-02
# 1   Griewank_F8   10   200   50.0 -5.753571e-03 -9.864672e-03  0.000000e+00
# 2   Griewank_F8   10  1000   10.0 -4.930694e-03 -7.396040e-03  0.000000e+00
# 3   Griewank_F8   10  1000   50.0  0.000000e+00  0.000000e+00  0.000000e+00
# 4   Griewank_F8   20   200   10.0 -9.024592e-03 -1.967773e-02  0.000000e+00
# ..          ...  ...   ...    ...           ...           ...           ...
# 59    Sphere_F1   50  1000   50.0 -2.671650e-07 -4.897369e-07 -1.356801e-07
# 60    Sphere_F1  100   200   10.0 -6.711692e+00 -1.156982e+01 -3.647955e+00
# 61    Sphere_F1  100   200   50.0 -3.922223e+00 -5.210060e+00 -2.393594e+00
# 62    Sphere_F1  100  1000   10.0 -5.828638e-01 -6.947437e-01 -4.570058e-01
# 63    Sphere_F1  100  1000   50.0 -2.701506e-01 -3.002711e-01 -2.441596e-01
#
# [64 rows x 7 columns]

# %% [markdown]
# # Zadanie 2

# %%
def mutation1(x, N, sigma):
    d = len(x)
    return x + sigma * np.random.randn(N, d)


def mutation2(x, N, sigmas):
    d = len(x)
    return x + sigmas * np.random.randn(N, d)


def mutation3(x, N, S):
    d = len(x)
    return x + np.dot(np.random.randn(N, d), np.linalg.cholesky(S).T)

# %%
def test_mutation_1(x, obj_f, N=100, sigma=0.25):
    x_fitness = obj_f(np.array([x]))

    mutations = mutation1(x, N, sigma)
    fitness_vals = obj_f(mutations)

    better_cnt = np.sum((fitness_vals > x_fitness))
    best = np.max(fitness_vals)

    return {
        "better_cnt": better_cnt,
        "total" : N,
        "improvement": best - x_fitness,
        "best": best
    }

# %%
def test_mutation_2(x, obj_f, sigmas, N=100):
    x_fitness = obj_f(np.array([x]))

    mutations = mutation2(x, N, sigmas)
    fitness_vals = obj_f(mutations)

    better_cnt = np.sum((fitness_vals > x_fitness))
    best = np.max(fitness_vals)

    return {
        "better_cnt": better_cnt,
        "total" : N,
        "improvement": best - x_fitness,
        "best": best
    }

# %%
def test_mutation_3(x, obj_f, S, N=100):
    x_fitness = obj_f(np.array([x]))

    mutations = mutation3(x, N, S)
    fitness_vals = obj_f(mutations)

    better_cnt = np.sum((fitness_vals > x_fitness))
    best = np.max(fitness_vals)

    return {
        "better_cnt": better_cnt,
        "total" : N,
        "improvement": best - x_fitness,
        "best": best
    }

# %%
def run_tests(d, obj_f, bounds, repeats=100):
    low, high = bounds
    stats = {
        'm1': {'better_cnts': [], 'improvements': []},
        'm2': {'better_cnts': [], 'improvements': []},
        'm3': {'better_cnts': [], 'improvements': []}
    }

    sigma_m1 = 0.25
    sigmas_m2 = np.random.uniform(0.1, 1.0, d)

    A = np.random.rand(d, d)
    S_m3 = np.dot(A, A.transpose())

    for i in range(repeats):
        x_start = np.random.uniform(low, high, size=d)

        res1 = test_mutation_1(x_start, obj_f, N=100, sigma=sigma_m1)
        res2 = test_mutation_2(x_start, obj_f, sigmas=sigmas_m2, N=100)
        res3 = test_mutation_3(x_start, obj_f, S=S_m3, N=100)

        stats['m1']['better_cnts'].append(res1['better_cnt'])
        stats['m1']['improvements'].append(res1['improvement'])

        stats['m2']['better_cnts'].append(res2['better_cnt'])
        stats['m2']['improvements'].append(res2['improvement'])

        stats['m3']['better_cnts'].append(res3['better_cnt'])
        stats['m3']['improvements'].append(res3['improvement'])


    print(f"--- N={repeats}, d={d} ---")
    for model in ['m1', 'm2', 'm3']:
        avg_count = np.mean(stats[model]['better_cnts'])
        avg_imp = np.mean(stats[model]['improvements'])
        print(f"[{model.upper()}] Avg individuals better: {avg_count:.2f}% | Avg best fitness gain: {avg_imp:.4f}")

# %%
print("Sphere")
run_tests(d=10, obj_f=objective_function_F1, bounds=(-5.12, 5.12))
# Out:
# Sphere
# --- N=100, d=10 ---
# [M1] Avg individuals better: 45.10% | Avg best fitness gain: 10.8334
# [M2] Avg individuals better: 38.91% | Avg best fitness gain: 20.0238
# [M3] Avg individuals better: 21.56% | Avg best fitness gain: 28.2977

# %%
print("Rastrigin")
run_tests(d=10, obj_f=objective_function_F6, bounds=(-5.12, 5.12))
# Out:
# Rastrigin
# --- N=100, d=10 ---
# [M1] Avg individuals better: 42.86% | Avg best fitness gain: 47.7236
# [M2] Avg individuals better: 36.98% | Avg best fitness gain: 51.9953
# [M3] Avg individuals better: 23.72% | Avg best fitness gain: 51.2184

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse
from scipy.stats import chi2

def get_ellipse(cov_matrix, alpha=0.95):
    chi2_val = chi2.ppf(alpha, df=2)
    scale_factor = np.sqrt(chi2_val)
    eig_vals, eig_vecs = np.linalg.eigh(cov_matrix)

    width = 2 * scale_factor * np.sqrt(eig_vals[1])
    height = 2 * scale_factor * np.sqrt(eig_vals[0])

    largest_eigenvec = eig_vecs[:, 1]
    angle = np.degrees(np.arctan2(largest_eigenvec[1], largest_eigenvec[0]))

    return width, height, angle


N = 2000
alpha = 0.95
center = [0, 0]


sigma_1 = 1.5
S1 = (sigma_1**2) * np.identity(2)
points1 = np.random.randn(N, 2) @ np.linalg.cholesky(S1).T

sigmas_2 = [2.0, 1.0]
S2 = np.diag(np.array(sigmas_2)**2)
points2 = np.random.randn(N, 2) @ np.linalg.cholesky(S2).T


S3 = np.array([[1.5, 1.2],
               [1.2, 1.5]])
points3 = np.random.randn(N, 2) @ np.linalg.cholesky(S3).T


matrices = [S1, S2, S3]
points_list = [points1, points2, points3]
titles = ["M1", "M2", "M3"]

fig, axes = plt.subplots(1, 3, figsize=(18, 6))

for i, ax in enumerate(axes):
    S = matrices[i]
    pts = points_list[i]

    ax.scatter(pts[:, 0], pts[:, 1], s=2, alpha=0.3, color='gray')

    w, h, angle = get_ellipse(S, alpha=alpha)

    ell = Ellipse(xy=center, width=w, height=h, angle=angle,
                  edgecolor='red', facecolor='none', lw=3)
    ax.add_patch(ell)

    ax.set_title(f"{titles[i]}\nAxes: {w:.2f}, {h:.2f}")
    ax.set_aspect('equal')
    limit = 10
    ax.set_xlim(-limit, limit); ax.set_ylim(-limit, limit)
    ax.grid(True, linestyle=':')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Zadanie 3

# %%
def run_sphere_benchmark(mutation_model, S=None):
    benchmark_functions = {
        "Sphere_F1a": objective_function_F1a,
        "Sphere_F1b": objective_function_F1b,
        "Sphere_F1c": objective_function_F1c,
    }


    dims = [2]
    pop_sizes = [200, 1000]
    sigmas = [10.0, 50.0]
    T = 200
    num_runs = 3

    results = []

    for func_name, func in benchmark_functions.items():
        for d in dims:
            tau = 1.0 / np.sqrt(2.0 * d)
            tau_0 = 1.0 / np.sqrt(2.0 * np.sqrt(d))

            for N in pop_sizes:
                for sigma in sigmas:
                    for run in range(num_runs):
                        print(f"Running {func_name}, d={d}, N={N}, sigma={sigma}, run={run+1}/{num_runs}")

                        best_objective_value, best_chromosome, _, _, _ = es(
                            objective_function=func,
                            chromosome_length=d,
                            population_size=N,
                            number_of_iterations=T,
                            number_of_offspring=2 * N,
                            number_of_parents=2,
                            sigma=sigma,
                            tau=tau,
                            tau_0=tau_0,
                            S=S,
                            mutation_f=mutation_model,
                            log_frequency=-1, # disable logging
                        )

                        results.append({
                            "function": func_name,
                            "dim": d,
                            "N": N,
                            "sigma": sigma,
                            "best_objective_value": best_objective_value,
                        })

    return pd.DataFrame(results)

# %%
run_sphere_benchmark("mutation_1")
# Out:
# Running Sphere_F1a, d=2, N=200, sigma=10.0, run=1/3
# Running Sphere_F1a, d=2, N=200, sigma=10.0, run=2/3
# Running Sphere_F1a, d=2, N=200, sigma=10.0, run=3/3
# Running Sphere_F1a, d=2, N=200, sigma=50.0, run=1/3
# Running Sphere_F1a, d=2, N=200, sigma=50.0, run=2/3
# Running Sphere_F1a, d=2, N=200, sigma=50.0, run=3/3
# Running Sphere_F1a, d=2, N=1000, sigma=10.0, run=1/3
# Running Sphere_F1a, d=2, N=1000, sigma=10.0, run=2/3
# Running Sphere_F1a, d=2, N=1000, sigma=10.0, run=3/3
# Running Sphere_F1a, d=2, N=1000, sigma=50.0, run=1/3
# Running Sphere_F1a, d=2, N=1000, sigma=50.0, run=2/3
# Running Sphere_F1a, d=2, N=1000, sigma=50.0, run=3/3
# Running Sphere_F1b, d=2, N=200, sigma=10.0, run=1/3
# Running Sphere_F1b, d=2, N=200, sigma=10.0, run=2/3
# Running Sphere_F1b, d=2, N=200, sigma=10.0, run=3/3
# Running Sphere_F1b, d=2, N=200, sigma=50.0, run=1/3
# Running Sphere_F1b, d=2, N=200, sigma=50.0, run=2/3
# Running Sphere_F1b, d=2, N=200, sigma=50.0, run=3/3
# Running Sphere_F1b, d=2, N=1000, sigma=10.0, run=1/3
# Running Sphere_F1b, d=2, N=1000, sigma=10.0, run=2/3
# Running Sphere_F1b, d=2, N=1000, sigma=10.0, run=3/3
# Running Sphere_F1b, d=2, N=1000, sigma=50.0, run=1/3
# Running Sphere_F1b, d=2, N=1000, sigma=50.0, run=2/3
# Running Sphere_F1b, d=2, N=1000, sigma=50.0, run=3/3
# Running Sphere_F1c, d=2, N=200, sigma=10.0, run=1/3
# Running Sphere_F1c, d=2, N=200, sigma=10.0, run=2/3
# Running Sphere_F1c, d=2, N=200, sigma=10.0, run=3/3
# Running Sphere_F1c, d=2, N=200, sigma=50.0, run=1/3
# Running Sphere_F1c, d=2, N=200, sigma=50.0, run=2/3
# Running Sphere_F1c, d=2, N=200, sigma=50.0, run=3/3
# Running Sphere_F1c, d=2, N=1000, sigma=10.0, run=1/3
# Running Sphere_F1c, d=2, N=1000, sigma=10.0, run=2/3
# Running Sphere_F1c, d=2, N=1000, sigma=10.0, run=3/3
# Running Sphere_F1c, d=2, N=1000, sigma=50.0, run=1/3
# Running Sphere_F1c, d=2, N=1000, sigma=50.0, run=2/3
# Running Sphere_F1c, d=2, N=1000, sigma=50.0, run=3/3
#       function  dim     N  sigma  best_objective_value
# 0   Sphere_F1a    2   200   10.0         -2.023069e-83
# 1   Sphere_F1a    2   200   10.0         -1.746941e-84
# 2   Sphere_F1a    2   200   10.0         -7.584969e-86
# 3   Sphere_F1a    2   200   50.0         -3.531228e-83
# 4   Sphere_F1a    2   200   50.0         -6.520496e-84
# 5   Sphere_F1a    2   200   50.0         -1.074381e-84
# 6   Sphere_F1a    2  1000   10.0         -8.560378e-87
# 7   Sphere_F1a    2  1000   10.0         -3.163385e-86
# 8   Sphere_F1a    2  1000   10.0         -4.126082e-86
# 9   Sphere_F1a    2  1000   50.0         -1.061534e-85
# 10  Sphere_F1a    2  1000   50.0         -3.310607e-86
# 11  Sphere_F1a    2  1000   50.0         -6.080793e-86
# 12  Sphere_F1b    2   200   10.0         -2.883029e-29
# 13  Sphere_F1b    2   200   10.0         -5.482955e-30
# 14  Sphere_F1b    2   200   10.0         -1.414098e-27
# 15  Sphere_F1b    2   200   50.0         -1.560108e-27
# 16  Sphere_F1b    2   200   50.0         -1.507609e-28
# 17  Sphere_F1b    2   200   50.0         -3.318965e-31
# 18  Sphere_F1b    2  1000   10.0         -1.172859e-29
# 19  Sphere_F1b    2  1000   10.0         -4.934078e-29
# 20  Sphere_F1b    2  1000   10.0         -2.936490e-29
# 21  Sphere_F1b    2  1000   50.0         -1.979011e-32
# 22  Sphere_F1b    2  1000   50.0         -4.329686e-30
# 23  Sphere_F1b    2  1000   50.0         -1.267944e-29
# 24  Sphere_F1c    2   200   10.0         -5.910842e-85
# 25  Sphere_F1c    2   200   10.0         -4.803300e-85
# 26  Sphere_F1c    2   200   10.0         -3.087755e-85
# 27  Sphere_F1c    2   200   50.0         -5.687969e-87
# 28  Sphere_F1c    2   200   50.0         -1.431515e-85
# 29  Sphere_F1c    2   200   50.0         -5.440281e-86
# 30  Sphere_F1c    2  1000   10.0         -8.819003e-87
# 31  Sphere_F1c    2  1000   10.0         -3.401299e-87
# 32  Sphere_F1c    2  1000   10.0         -9.355322e-88
# 33  Sphere_F1c    2  1000   50.0         -1.162563e-86
# 34  Sphere_F1c    2  1000   50.0         -2.485963e-86
# 35  Sphere_F1c    2  1000   50.0         -9.065762e-88

# %%
run_sphere_benchmark("mutation_2")
# Out:
# Running Sphere_F1a, d=2, N=200, sigma=10.0, run=1/3
# Running Sphere_F1a, d=2, N=200, sigma=10.0, run=2/3
# Running Sphere_F1a, d=2, N=200, sigma=10.0, run=3/3
# Running Sphere_F1a, d=2, N=200, sigma=50.0, run=1/3
# Running Sphere_F1a, d=2, N=200, sigma=50.0, run=2/3
# Running Sphere_F1a, d=2, N=200, sigma=50.0, run=3/3
# Running Sphere_F1a, d=2, N=1000, sigma=10.0, run=1/3
# Running Sphere_F1a, d=2, N=1000, sigma=10.0, run=2/3
# Running Sphere_F1a, d=2, N=1000, sigma=10.0, run=3/3
# Running Sphere_F1a, d=2, N=1000, sigma=50.0, run=1/3
# Running Sphere_F1a, d=2, N=1000, sigma=50.0, run=2/3
# Running Sphere_F1a, d=2, N=1000, sigma=50.0, run=3/3
# Running Sphere_F1b, d=2, N=200, sigma=10.0, run=1/3
# Running Sphere_F1b, d=2, N=200, sigma=10.0, run=2/3
# Running Sphere_F1b, d=2, N=200, sigma=10.0, run=3/3
# Running Sphere_F1b, d=2, N=200, sigma=50.0, run=1/3
# Running Sphere_F1b, d=2, N=200, sigma=50.0, run=2/3
# Running Sphere_F1b, d=2, N=200, sigma=50.0, run=3/3
# Running Sphere_F1b, d=2, N=1000, sigma=10.0, run=1/3
# Running Sphere_F1b, d=2, N=1000, sigma=10.0, run=2/3
# Running Sphere_F1b, d=2, N=1000, sigma=10.0, run=3/3
# Running Sphere_F1b, d=2, N=1000, sigma=50.0, run=1/3
# Running Sphere_F1b, d=2, N=1000, sigma=50.0, run=2/3
# Running Sphere_F1b, d=2, N=1000, sigma=50.0, run=3/3
# Running Sphere_F1c, d=2, N=200, sigma=10.0, run=1/3
# Running Sphere_F1c, d=2, N=200, sigma=10.0, run=2/3
# Running Sphere_F1c, d=2, N=200, sigma=10.0, run=3/3
# Running Sphere_F1c, d=2, N=200, sigma=50.0, run=1/3
# Running Sphere_F1c, d=2, N=200, sigma=50.0, run=2/3
# Running Sphere_F1c, d=2, N=200, sigma=50.0, run=3/3
# Running Sphere_F1c, d=2, N=1000, sigma=10.0, run=1/3
# Running Sphere_F1c, d=2, N=1000, sigma=10.0, run=2/3
# Running Sphere_F1c, d=2, N=1000, sigma=10.0, run=3/3
# Running Sphere_F1c, d=2, N=1000, sigma=50.0, run=1/3
# Running Sphere_F1c, d=2, N=1000, sigma=50.0, run=2/3
# Running Sphere_F1c, d=2, N=1000, sigma=50.0, run=3/3
#       function  dim     N  sigma  best_objective_value
# 0   Sphere_F1a    2   200   10.0         -1.349611e-70
# 1   Sphere_F1a    2   200   10.0         -1.481062e-71
# 2   Sphere_F1a    2   200   10.0         -3.313667e-70
# 3   Sphere_F1a    2   200   50.0         -2.785863e-70
# 4   Sphere_F1a    2   200   50.0         -1.700606e-70
# 5   Sphere_F1a    2   200   50.0         -6.812139e-70
# 6   Sphere_F1a    2  1000   10.0         -7.288256e-72
# 7   Sphere_F1a    2  1000   10.0         -2.370551e-72
# 8   Sphere_F1a    2  1000   10.0         -2.155968e-72
# 9   Sphere_F1a    2  1000   50.0         -3.130912e-72
# 10  Sphere_F1a    2  1000   50.0         -6.495783e-72
# 11  Sphere_F1a    2  1000   50.0         -1.864533e-73
# 12  Sphere_F1b    2   200   10.0         -6.465105e-69
# 13  Sphere_F1b    2   200   10.0         -3.802303e-70
# 14  Sphere_F1b    2   200   10.0         -5.902129e-68
# 15  Sphere_F1b    2   200   50.0         -5.068709e-67
# 16  Sphere_F1b    2   200   50.0         -7.509113e-69
# 17  Sphere_F1b    2   200   50.0         -6.061923e-69
# 18  Sphere_F1b    2  1000   10.0         -5.296552e-70
# 19  Sphere_F1b    2  1000   10.0         -3.521374e-70
# 20  Sphere_F1b    2  1000   10.0         -3.611073e-70
# 21  Sphere_F1b    2  1000   50.0         -1.323528e-70
# 22  Sphere_F1b    2  1000   50.0         -4.152927e-70
# 23  Sphere_F1b    2  1000   50.0         -1.891519e-70
# 24  Sphere_F1c    2   200   10.0         -2.239663e-69
# 25  Sphere_F1c    2   200   10.0         -1.930824e-68
# 26  Sphere_F1c    2   200   10.0         -1.011473e-68
# 27  Sphere_F1c    2   200   50.0         -1.779487e-67
# 28  Sphere_F1c    2   200   50.0         -5.106751e-68
# 29  Sphere_F1c    2   200   50.0         -7.936237e-70
# 30  Sphere_F1c    2  1000   10.0         -3.098566e-69
# 31  Sphere_F1c    2  1000   10.0         -8.931198e-71
# 32  Sphere_F1c    2  1000   10.0         -1.298130e-69
# 33  Sphere_F1c    2  1000   50.0         -2.175286e-69
# 34  Sphere_F1c    2  1000   50.0         -2.056653e-70
# 35  Sphere_F1c    2  1000   50.0         -8.476171e-70

# %%
A = np.random.rand(d, d)
S = np.dot(A, A.transpose())
run_sphere_benchmark("mutation_3", S)
# Out:
# Running Sphere_F1a, d=2, N=200, sigma=10.0, run=1/3
# Running Sphere_F1a, d=2, N=200, sigma=10.0, run=2/3
# Running Sphere_F1a, d=2, N=200, sigma=10.0, run=3/3
# Running Sphere_F1a, d=2, N=200, sigma=50.0, run=1/3
# Running Sphere_F1a, d=2, N=200, sigma=50.0, run=2/3
# Running Sphere_F1a, d=2, N=200, sigma=50.0, run=3/3
# Running Sphere_F1a, d=2, N=1000, sigma=10.0, run=1/3
# Running Sphere_F1a, d=2, N=1000, sigma=10.0, run=2/3
# Running Sphere_F1a, d=2, N=1000, sigma=10.0, run=3/3
# Running Sphere_F1a, d=2, N=1000, sigma=50.0, run=1/3
# Running Sphere_F1a, d=2, N=1000, sigma=50.0, run=2/3
# Running Sphere_F1a, d=2, N=1000, sigma=50.0, run=3/3
# Running Sphere_F1b, d=2, N=200, sigma=10.0, run=1/3
# Running Sphere_F1b, d=2, N=200, sigma=10.0, run=2/3
# Running Sphere_F1b, d=2, N=200, sigma=10.0, run=3/3
# Running Sphere_F1b, d=2, N=200, sigma=50.0, run=1/3
# Running Sphere_F1b, d=2, N=200, sigma=50.0, run=2/3
# Running Sphere_F1b, d=2, N=200, sigma=50.0, run=3/3
# Running Sphere_F1b, d=2, N=1000, sigma=10.0, run=1/3
# Running Sphere_F1b, d=2, N=1000, sigma=10.0, run=2/3
# Running Sphere_F1b, d=2, N=1000, sigma=10.0, run=3/3
# Running Sphere_F1b, d=2, N=1000, sigma=50.0, run=1/3
# Running Sphere_F1b, d=2, N=1000, sigma=50.0, run=2/3
# Running Sphere_F1b, d=2, N=1000, sigma=50.0, run=3/3
# Running Sphere_F1c, d=2, N=200, sigma=10.0, run=1/3
# Running Sphere_F1c, d=2, N=200, sigma=10.0, run=2/3
# Running Sphere_F1c, d=2, N=200, sigma=10.0, run=3/3
# Running Sphere_F1c, d=2, N=200, sigma=50.0, run=1/3
# Running Sphere_F1c, d=2, N=200, sigma=50.0, run=2/3
# Running Sphere_F1c, d=2, N=200, sigma=50.0, run=3/3
# Running Sphere_F1c, d=2, N=1000, sigma=10.0, run=1/3
# Running Sphere_F1c, d=2, N=1000, sigma=10.0, run=2/3
# Running Sphere_F1c, d=2, N=1000, sigma=10.0, run=3/3
# Running Sphere_F1c, d=2, N=1000, sigma=50.0, run=1/3
# Running Sphere_F1c, d=2, N=1000, sigma=50.0, run=2/3
# Running Sphere_F1c, d=2, N=1000, sigma=50.0, run=3/3
#       function  dim     N  sigma  best_objective_value
# 0   Sphere_F1a    2   200   10.0         -2.863574e-27
# 1   Sphere_F1a    2   200   10.0         -3.270256e-15
# 2   Sphere_F1a    2   200   10.0         -3.938395e-18
# 3   Sphere_F1a    2   200   50.0         -7.862771e-18
# 4   Sphere_F1a    2   200   50.0         -2.176009e-45
# 5   Sphere_F1a    2   200   50.0         -7.212529e-22
# 6   Sphere_F1a    2  1000   10.0         -4.170381e-32
# 7   Sphere_F1a    2  1000   10.0         -6.849816e-22
# 8   Sphere_F1a    2  1000   10.0         -7.690328e-18
# 9   Sphere_F1a    2  1000   50.0         -4.384444e-29
# 10  Sphere_F1a    2  1000   50.0         -3.297544e-46
# 11  Sphere_F1a    2  1000   50.0         -4.741187e-23
# 12  Sphere_F1b    2   200   10.0         -3.406749e+01
# 13  Sphere_F1b    2   200   10.0         -3.527585e-01
# 14  Sphere_F1b    2   200   10.0         -1.142336e+02
# 15  Sphere_F1b    2   200   50.0         -2.391815e-02
# 16  Sphere_F1b    2   200   50.0         -3.086975e+00
# 17  Sphere_F1b    2   200   50.0         -2.990867e-01
# 18  Sphere_F1b    2  1000   10.0         -1.182563e-01
# 19  Sphere_F1b    2  1000   10.0         -1.058506e-01
# 20  Sphere_F1b    2  1000   10.0         -4.962054e-03
# 21  Sphere_F1b    2  1000   50.0         -2.989751e-03
# 22  Sphere_F1b    2  1000   50.0         -4.341945e-02
# 23  Sphere_F1b    2  1000   50.0         -6.506854e-03
# 24  Sphere_F1c    2   200   10.0         -4.703585e-47
# 25  Sphere_F1c    2   200   10.0         -1.950849e-39
# 26  Sphere_F1c    2   200   10.0         -2.509282e-51
# 27  Sphere_F1c    2   200   50.0         -7.228488e-40
# 28  Sphere_F1c    2   200   50.0         -4.294422e-63
# 29  Sphere_F1c    2   200   50.0         -1.347929e-73
# 30  Sphere_F1c    2  1000   10.0         -4.009617e-74
# 31  Sphere_F1c    2  1000   10.0         -1.530738e-76
# 32  Sphere_F1c    2  1000   10.0         -2.211597e-70
# 33  Sphere_F1c    2  1000   50.0         -4.706951e-75
# 34  Sphere_F1c    2  1000   50.0         -1.924800e-54
# 35  Sphere_F1c    2  1000   50.0         -2.704573e-75
